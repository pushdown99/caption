# %%
from caption.config import config, flickr8k_opts, coco2014_opts, vgg16_opts, inceptionv3_opts, efficientnet_opt
from caption.utils import usage
#from caption.models    import flickr8k, coco2014, vgg16, inceptionv3, EfficientNetB0, Encoder, Decoder, BahdanauAttention
from caption.models    import flickr8k, coco2014, vgg16
from caption import utils
from keras.backend import clear_session

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

usage()
# Out:
# 2022-10-05 15:04:54.545778: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-05 15:04:54.709756: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-10-05 15:04:54.763137: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
model = vgg16.model1 (config, coco2014_opts, vgg16_opts)
# Out:
# 2022-10-05 15:04:58.075989: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-05 15:04:59.069885: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30490 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:00:09.0, compute capability: 7.0
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
# ...

# %%
model.Generate ()
# Out:
#   Original 1: view of kitchen with burner top stove
#   Original 2: this kitchen has white stove and all white cabinets
#   Original 3: kitchen with stove microwave and cabinets
#   Original 4: kitchen with microwave stove and cabinets
#   Original 5: white kitchen with gas stove and microwave
# 2022-10-05 15:06:00.375583: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
#   Sampling (BLEU-1: 75.000000): kitchen with sink sink and microwave
#   Beam Search k=3 (BLEU-1: 50.000000): kitchen that has sink and sink in it
#   Beam Search k=5 (BLEU-1: 44.444444): an empty kitchen with stainless steel appliances
#   Original 1: boat and duck is in the water
#   Original 2: this is an image of bird on buoy with boat nearby
#   Original 3: this is bird standing on buoy with boat behind it
#   Original 4: bird standing on buoy in large body of water
#   Original 5: segull sits on floatation device looking at boat on the water
# ...
